# %% [markdown]
# This is a preprocessing step for celeb fake face dataset and saving it in another folder pre_processed

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob
import os
import cv2
import face_recognition

# Define the path to the input video files
input_video_files = glob.glob('/content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/*.mp4')

# Define the output directory
output_directory = '/content/drive/My Drive/Pre_processed/pre_dfdc_fake_face/'

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# Function to extract frames from a video
def frame_extract(path):
    vidObj = cv2.VideoCapture(path)
    success = 1
    while success:
        success, image = vidObj.read()
        if success:
            yield image

# Function to create face videos
def create_face_videos(path_list, out_dir):
    print("Number of video files found:", len(path_list))
    for path in path_list:
        out_path = os.path.join(out_dir, os.path.basename(path))
        if os.path.exists(out_path):
            print("File Already exists: ", out_path)
            continue
        print("Processing video:", path)
        frames = []
        out = cv2.VideoWriter(out_path, cv2.VideoWriter_fourcc('M', 'J', 'P', 'G'), 30, (112, 112))
        for idx, frame in enumerate(frame_extract(path)):
            if idx <= 150:
                frames.append(frame)
                if len(frames) == 4:
                    faces = face_recognition.batch_face_locations(frames)
                    for i, face in enumerate(faces):
                        if len(face) != 0:
                            top, right, bottom, left = face[0]
                            try:
                                out.write(cv2.resize(frames[i][top:bottom, left:right, :], (112, 112)))
                            except Exception as e:
                                print(f"Error writing frame to video: {e}")
                    frames = []
        out.release()

# Calling the function with the appropriate paths
create_face_videos(input_video_files, output_directory)
# Out:
# Number of video files found: 1566
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abiotberut.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abvgbvoxco.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abssilrpat.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/accuranbpc.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abygnkrrix.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acgywoqfbr.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abaodketae.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abdxzlhagb.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abxtkdjyru.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acagallncj.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/ablzpwqhcc.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abfvpzjkwr.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abebnhqyzv.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acdkfksyev.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aakkdgsmvl.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aaprcuxsdb.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abjvfvhtnp.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abiodyryai.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aawhvztjdt.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aauhqwwncp.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abahildqna.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aaknzywids.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abeibpdqhj.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abhqmggsqu.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abgunexqlc.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abhggqdift.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aaqaifqrwn.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aavyetamvt.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aaaoqepxnf.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/abddemeing.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aaujbbfhqu.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aaoecyszps.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aarsmohwrt.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aafezqchru.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aassnaulhq.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aahslbfkop.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aabdnomlru.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aahsnkchkz.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aaagqkcdis.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aabkwhhgwv.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aajhbrxhzm.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aelsfznuqw.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aedbjztjwz.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/afvdmlwwyr.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/afvldbcclm.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/afovojcvgh.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/afnhmtuuva.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/afdblocyhi.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aezvgaqjpf.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aeyprmocjo.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aelvskvush.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/afvefokzbu.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adxtihgjrs.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aentwuqfmv.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adtvlinjvb.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aemuyscfmg.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aeconjpzxx.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/afrwgxjdqz.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/afposymfjh.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aegwmawqov.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adaoqecjet.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aeuyruleqo.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aeudhfvcvk.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aeuxknmacb.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aejvkfbtxs.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adftmlvzfs.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aebgvmafzx.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aczigtxrgf.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acjjzzvzvg.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aesicqmigv.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adcnvlhawy.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aesqljtwep.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adlucxlfvr.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aegvtnwqoe.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aebenljufi.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/addyjceutz.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adqyqmibof.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adsxpxgjlp.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adfteyuomy.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/addkktdymg.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aczofflgti.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acpaumltcm.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adnnnmoqek.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adckadazdl.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/achofoxrpx.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acyvmvapdl.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/achcojqaas.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acptlizllc.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acryukkddn.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acukjpjxen.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aciykyosuy.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/acsnnvnvhy.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/adpobgciet.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/achakioceb.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/aciecilrsg.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/achdeirhym.mp4
# Processing video: /content/drive/My Drive/dataset_unzip/DFDC_FAKE_Face/